# %% [markdown]
# # 📘 M2C2 DataKit Notebook: Universal Loading, Assurance, and Scoring
#
# This notebook demonstrates a full analytic pipeline using the `m2c2-datakit` package. It uses the `LASSIE` class to load, validate, score, and optionally export data from multiple source types.
#
# ---
#
# ## 🎯 Purpose
#
# Enable researchers to plug in data from varied sources (e.g., MongoDB, UAS, MetricWire, CSV bundles) and apply a consistent pipeline for:
#
# - Input validation
#
# - Scoring via predefined rules
#
# - Inspection and summarization
#
# - Tidy export and codebook generation
#
# ---
#
# ## Inspired by:
#
# <img src="https://m.media-amazon.com/images/M/MV5BNDNkZDk0ODktYjc0My00MzY4LWE3NzgtNjU5NmMzZDA3YTA1XkEyXkFqcGc@._V1_FMjpg_UX1000_.jpg" alt="Inspiration for Package, Lassie Movie" width="100"/>
#
# ## 🧠 L.A.S.S.I.E. Pipeline Summary
#
# | Step | Method           | Purpose                                                                 |
# |------|------------------|-------------------------------------------------------------------------|
# | L    | `load()`         | Load raw data from a supported source (e.g., MongoDB, UAS, MetricWire). |
# | A    | `assure()`       | Validate that required columns exist before processing.                 |
# | S    | `score()`        | Apply scoring logic based on predefined or custom rules.                |
# | S    | `summarize()`    | Aggregate scored data by participant, session, or custom groups.        |
# | I    | `inspect()`      | Visualize distributions or pairwise plots for quality checks.           |
# | E    | `export()`       | Save scored and summarized data to tidy files and optionally metadata.  |
#
# ---

# %% [markdown]
# ## Verify Data

# %% [markdown]
# ## 🛠️ Setup for Developers of this Package

# %% [markdown]
# ## Setup Environment to run Notebook

# %%
# !make dev-install
# %pip install --upgrade --no-cache-dir m2c2_datakit
# Out:
# rm -rf dist build *.egg-info .venv
# uv venv .venv --python=/opt/homebrew/bin/python3.10
# Using CPython 3.10.16 interpreter at: /opt/homebrew/opt/python@3.10/bin/python3.10
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# uv pip install --python=.venv/bin/python -r requirements.txt --no-cache-dir m2c2_datakit
# Resolved 92 packages in 2.44s
# ⠙ Preparing packages... (0/92)
# ⠙ Preparing packages... (0/92)---     0 B/1.50 MiB
# pydantic   ------------------------------     0 B/433.50 KiB
# ⠙ Preparing packages... (0/92)---     0 B/1.50 MiB
# toolz      ------------------------------     0 B/55.06 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# ⠙ Preparing packages... (0/92)---     0 B/1.50 MiB
# toolz      ------------------------------     0 B/55.06 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# ⠙ Preparing packages... (0/92)---     0 B/1.50 MiB
# toolz      ------------------------------     0 B/55.06 KiB
# certifi    ------------------------------     0 B/155.88 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# ⠙ Preparing packages... (0/92)---     0 B/1.50 MiB
# toolz      ------------------------------     0 B/55.06 KiB
# ipykernel  ------------------------------     0 B/114.43 KiB
# certifi    ------------------------------     0 B/155.88 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# ⠙ Preparing packages... (0/92)---     0 B/1.50 MiB
# toolz      ------------------------------     0 B/55.06 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# ipykernel  ------------------------------     0 B/114.43 KiB
# certifi    ------------------------------     0 B/155.88 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# ⠙ Preparing packages... (0/92)---     0 B/1.50 MiB
# toolz      ------------------------------     0 B/55.06 KiB
# opentelemetry-api ------------------------------     0 B/64.23 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# ipykernel  ------------------------------     0 B/114.43 KiB
# certifi    ------------------------------     0 B/155.88 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# ⠙ Preparing packages... (0/92)---     0 B/1.50 MiB
# opentelemetry-proto ------------------------------     0 B/54.55 KiB
# toolz      ------------------------------     0 B/55.06 KiB
# opentelemetry-api ------------------------------     0 B/64.23 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# ipykernel  ------------------------------     0 B/114.43 KiB
# certifi    ------------------------------     0 B/155.88 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# ⠙ Preparing packages... (0/92)---     0 B/1.50 MiB
# opentelemetry-proto ------------------------------     0 B/54.55 KiB
# toolz      ------------------------------     0 B/55.06 KiB
# opentelemetry-api ------------------------------     0 B/64.23 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# ipykernel  ------------------------------     0 B/114.43 KiB
# certifi    ------------------------------     0 B/155.88 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# ⠙ Preparing packages... (0/92)--- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------     0 B/54.55 KiB
# toolz      ------------------------------     0 B/55.06 KiB
# opentelemetry-api ------------------------------     0 B/64.23 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# ipykernel  ------------------------------     0 B/114.43 KiB
# certifi    ------------------------------     0 B/155.88 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# pydantic   ------------------------------ 14.91 KiB/433.50 KiB
# ⠙ Preparing packages... (0/92)--- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------     0 B/54.55 KiB
# toolz      ------------------------------ 14.92 KiB/55.06 KiB
# opentelemetry-api ------------------------------     0 B/64.23 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# ipykernel  ------------------------------     0 B/114.43 KiB
# certifi    ------------------------------     0 B/155.88 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# pydantic   ------------------------------ 14.91 KiB/433.50 KiB
# ⠙ Preparing packages... (0/92)--- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------     0 B/54.55 KiB
# toolz      ------------------------------ 14.92 KiB/55.06 KiB
# opentelemetry-api ------------------------------     0 B/64.23 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# ipykernel  ------------------------------     0 B/114.43 KiB
# certifi    ------------------------------     0 B/155.88 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# pydantic   ------------------------------ 14.91 KiB/433.50 KiB
# ⠙ Preparing packages... (0/92)--- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------     0 B/54.55 KiB
# toolz      ------------------------------ 14.92 KiB/55.06 KiB
# opentelemetry-api ------------------------------     0 B/64.23 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# ipykernel  ------------------------------     0 B/114.43 KiB
# certifi    ------------------------------ 14.91 KiB/155.88 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# pydantic   ------------------------------ 14.91 KiB/433.50 KiB
# ⠙ Preparing packages... (0/92)--- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------     0 B/54.55 KiB
# toolz      ------------------------------ 14.92 KiB/55.06 KiB
# opentelemetry-api ------------------------------     0 B/64.23 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# ipykernel  ------------------------------ 14.91 KiB/114.43 KiB
# certifi    ------------------------------ 14.91 KiB/155.88 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# pydantic   ------------------------------ 14.91 KiB/433.50 KiB
# ⠙ Preparing packages... (0/92)--- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------     0 B/54.55 KiB
# toolz      ------------------------------ 14.92 KiB/55.06 KiB
# opentelemetry-api ------------------------------     0 B/64.23 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# ipykernel  ------------------------------ 14.91 KiB/114.43 KiB
# certifi    ------------------------------ 14.91 KiB/155.88 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# pydantic   ------------------------------ 14.91 KiB/433.50 KiB
# ⠙ Preparing packages... (0/92)--- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------     0 B/54.55 KiB
# toolz      ------------------------------ 14.92 KiB/55.06 KiB
# opentelemetry-api ------------------------------ 14.91 KiB/64.23 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# ipykernel  ------------------------------ 14.91 KiB/114.43 KiB
# certifi    ------------------------------ 14.91 KiB/155.88 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# pydantic   ------------------------------ 14.91 KiB/433.50 KiB
# ⠙ Preparing packages... (0/92)--- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------ 4.85 KiB/54.55 KiB
# toolz      ------------------------------ 14.92 KiB/55.06 KiB
# opentelemetry-api ------------------------------ 14.91 KiB/64.23 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# ipykernel  ------------------------------ 14.91 KiB/114.43 KiB
# certifi    ------------------------------ 14.91 KiB/155.88 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# pydantic   ------------------------------ 14.91 KiB/433.50 KiB
# ⠙ Preparing packages... (0/92)--- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------ 4.85 KiB/54.55 KiB
# toolz      ------------------------------ 14.92 KiB/55.06 KiB
# opentelemetry-api ------------------------------ 14.91 KiB/64.23 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# ipykernel  ------------------------------ 14.91 KiB/114.43 KiB
# certifi    ------------------------------ 14.91 KiB/155.88 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# pydantic   ------------------------------ 14.91 KiB/433.50 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# ⠙ Preparing packages... (0/92)-- 14.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.55 KiB
# toolz      ------------------------------ 14.92 KiB/55.06 KiB
# kiwisolver ------------------------------ 14.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 14.91 KiB/64.23 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# idna       ------------------------------     0 B/68.79 KiB
# ipykernel  ------------------------------ 30.91 KiB/114.43 KiB
# certifi    ------------------------------ 23.27 KiB/155.88 KiB
# python-dateutil ------------------------------ 30.90 KiB/224.50 KiB
# rich       ------------------------------     0 B/237.53 KiB
# googleapis-common-protos ------------------------------ 14.90 KiB/287.63 KiB
# protobuf   ------------------------------ 14.95 KiB/408.03 KiB
# pydantic   ------------------------------ 30.91 KiB/433.50 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# xarray     ------------------------------     0 B/1.23 MiB
# ⠙ Preparing packages... (0/92)-- 30.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------ 14.90 KiB/54.55 KiB
# toolz      ------------------------------ 30.92 KiB/55.06 KiB
# kiwisolver ------------------------------ 14.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 30.91 KiB/64.23 KiB
# packaging  ------------------------------ 30.91 KiB/64.91 KiB
# idna       ------------------------------ 14.92 KiB/68.79 KiB
# traitlets  ------------------------------     0 B/83.36 KiB
# parso      ------------------------------     0 B/101.22 KiB
# pyparsing  ------------------------------     0 B/108.52 KiB
# ipykernel  ------------------------------ 30.91 KiB/114.43 KiB
# certifi    ------------------------------ 39.27 KiB/155.88 KiB
# python-dateutil ------------------------------ 31.57 KiB/224.50 KiB
# rich       ------------------------------ 14.92 KiB/237.53 KiB
# googleapis-common-protos ------------------------------ 14.90 KiB/287.63 KiB
# protobuf   ------------------------------ 30.95 KiB/408.03 KiB
# pydantic   ------------------------------ 46.91 KiB/433.50 KiB
# pytz       ------------------------------ 30.91 KiB/497.29 KiB
# ipython    ------------------------------     0 B/811.60 KiB
# setuptools ------------------------------     0 B/1.15 MiB
# xarray     ------------------------------     0 B/1.23 MiB
# ⠹ Preparing packages... (0/92)-- 46.91 KiB/1.50 MiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.55 KiB
# toolz      ------------------------------ 44.76 KiB/55.06 KiB
# kiwisolver ------------------------------ 30.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 46.91 KiB/64.23 KiB
# packaging  ------------------------------ 46.91 KiB/64.91 KiB
# idna       ------------------------------ 14.92 KiB/68.79 KiB
# traitlets  ------------------------------     0 B/83.36 KiB
# parso      ------------------------------     0 B/101.22 KiB
# pyparsing  ------------------------------ 14.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 46.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------     0 B/116.08 KiB
# urllib3    ------------------------------     0 B/125.66 KiB
# certifi    ------------------------------ 39.27 KiB/155.88 KiB
# python-dateutil ------------------------------ 31.57 KiB/224.50 KiB
# psutil     ------------------------------     0 B/233.92 KiB
# rich       ------------------------------ 14.92 KiB/237.53 KiB
# googleapis-common-protos ------------------------------ 30.90 KiB/287.63 KiB
# seaborn    ------------------------------     0 B/288.00 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# protobuf   ------------------------------ 30.95 KiB/408.03 KiB
# pydantic   ------------------------------ 46.91 KiB/433.50 KiB
# pytz       ------------------------------ 30.91 KiB/497.29 KiB
# ⠹ Preparing packages... (0/92)--     0 B/811.60 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.55 KiB
# toolz      ------------------------------ 44.76 KiB/55.06 KiB
# pexpect    ------------------------------     0 B/62.28 KiB
# requests   ------------------------------ 14.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 30.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 46.91 KiB/64.23 KiB
# packaging  ------------------------------ 46.91 KiB/64.91 KiB
# idna       ------------------------------ 14.92 KiB/68.79 KiB
# traitlets  ------------------------------ 14.94 KiB/83.36 KiB
# markdown-it-py ------------------------------     0 B/85.48 KiB
# parso      ------------------------------ 14.91 KiB/101.22 KiB
# jupyter-client ------------------------------     0 B/103.62 KiB
# pyparsing  ------------------------------ 14.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 46.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 14.90 KiB/116.08 KiB
# urllib3    ------------------------------ 14.92 KiB/125.66 KiB
# certifi    ------------------------------ 39.27 KiB/155.88 KiB
# logfire    ------------------------------ 8.51 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 14.89 KiB/190.37 KiB
# charset-normalizer ------------------------------     0 B/197.09 KiB
# python-dateutil ------------------------------ 31.57 KiB/224.50 KiB
# ⠹ Preparing packages... (0/92)-- 8.71 KiB/233.92 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/54.55 KiB
# toolz      ------------------------------ 44.76 KiB/55.06 KiB
# pexpect    ------------------------------     0 B/62.28 KiB
# requests   ------------------------------ 14.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 30.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 46.91 KiB/64.23 KiB
# packaging  ------------------------------ 46.91 KiB/64.91 KiB
# idna       ------------------------------ 30.92 KiB/68.79 KiB
# traitlets  ------------------------------ 14.94 KiB/83.36 KiB
# markdown-it-py ------------------------------     0 B/85.48 KiB
# parso      ------------------------------ 14.91 KiB/101.22 KiB
# jupyter-client ------------------------------     0 B/103.62 KiB
# pyparsing  ------------------------------ 14.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 46.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 14.90 KiB/116.08 KiB
# urllib3    ------------------------------ 14.92 KiB/125.66 KiB
# certifi    ------------------------------ 41.29 KiB/155.88 KiB
# logfire    ------------------------------ 8.51 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 14.89 KiB/190.37 KiB
# charset-normalizer ------------------------------     0 B/197.09 KiB
# python-dateutil ------------------------------ 47.57 KiB/224.50 KiB
# ⠹ Preparing packages... (0/92)-- 8.71 KiB/233.92 KiB
# opentelemetry-proto ------------------------------ 46.90 KiB/54.55 KiB
# pexpect    ------------------------------     0 B/62.28 KiB
# requests   ------------------------------ 14.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 46.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 52.49 KiB/64.23 KiB
# packaging  ------------------------------ 62.91 KiB/64.91 KiB
# idna       ------------------------------ 30.92 KiB/68.79 KiB
# traitlets  ------------------------------ 14.94 KiB/83.36 KiB
# markdown-it-py ------------------------------     0 B/85.48 KiB
# parso      ------------------------------ 14.91 KiB/101.22 KiB
# jupyter-client ------------------------------     0 B/103.62 KiB
# pyparsing  ------------------------------ 14.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 62.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 14.90 KiB/116.08 KiB
# urllib3    ------------------------------ 14.92 KiB/125.66 KiB
# certifi    ------------------------------ 41.29 KiB/155.88 KiB
# logfire    ------------------------------ 8.51 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 14.89 KiB/190.37 KiB
# charset-normalizer ------------------------------     0 B/197.09 KiB
# python-dateutil ------------------------------ 47.57 KiB/224.50 KiB
# psutil     ------------------------------ 8.71 KiB/233.92 KiB
# ⠸ Preparing packages... (1/92)-- 30.92 KiB/237.53 KiB
# opentelemetry-proto ------------------------------ 46.90 KiB/54.55 KiB
# pexpect    ------------------------------     0 B/62.28 KiB
# requests   ------------------------------ 14.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 46.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 52.49 KiB/64.23 KiB
# packaging  ------------------------------ 62.91 KiB/64.91 KiB
# idna       ------------------------------ 30.92 KiB/68.79 KiB
# traitlets  ------------------------------ 14.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 16.00 KiB/85.48 KiB
# parso      ------------------------------ 14.91 KiB/101.22 KiB
# jupyter-client ------------------------------     0 B/103.62 KiB
# pyparsing  ------------------------------ 14.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 62.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 14.90 KiB/116.08 KiB
# urllib3    ------------------------------ 14.92 KiB/125.66 KiB
# certifi    ------------------------------ 41.29 KiB/155.88 KiB
# logfire    ------------------------------ 8.51 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 14.89 KiB/190.37 KiB
# charset-normalizer ------------------------------     0 B/197.09 KiB
# python-dateutil ------------------------------ 47.57 KiB/224.50 KiB
# psutil     ------------------------------ 8.71 KiB/233.92 KiB
# ⠸ Preparing packages... (1/92)-- 30.92 KiB/237.53 KiB
# opentelemetry-proto ------------------------------ 46.90 KiB/54.55 KiB
# pexpect    ------------------------------ 16.00 KiB/62.28 KiB
# requests   ------------------------------ 14.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 46.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 52.49 KiB/64.23 KiB
# packaging  ------------------------------ 62.91 KiB/64.91 KiB
# idna       ------------------------------ 30.92 KiB/68.79 KiB
# traitlets  ------------------------------ 30.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 16.00 KiB/85.48 KiB
# parso      ------------------------------ 30.91 KiB/101.22 KiB
# jupyter-client ------------------------------ 15.89 KiB/103.62 KiB
# pyparsing  ------------------------------ 30.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 62.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 14.90 KiB/116.08 KiB
# urllib3    ------------------------------ 14.92 KiB/125.66 KiB
# certifi    ------------------------------ 41.29 KiB/155.88 KiB
# logfire    ------------------------------ 8.51 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 14.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 14.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 47.57 KiB/224.50 KiB
# psutil     ------------------------------ 14.95 KiB/233.92 KiB
# ⠸ Preparing packages... (1/92)-- 30.92 KiB/237.53 KiB
# opentelemetry-proto ------------------------------ 46.90 KiB/54.55 KiB
# pexpect    ------------------------------ 16.00 KiB/62.28 KiB
# requests   ------------------------------ 30.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 46.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 52.49 KiB/64.23 KiB
# packaging  ------------------------------ 62.91 KiB/64.91 KiB
# idna       ------------------------------ 30.92 KiB/68.79 KiB
# traitlets  ------------------------------ 30.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 16.00 KiB/85.48 KiB
# parso      ------------------------------ 30.91 KiB/101.22 KiB
# jupyter-client ------------------------------ 15.89 KiB/103.62 KiB
# pyparsing  ------------------------------ 30.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 62.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 30.90 KiB/116.08 KiB
# urllib3    ------------------------------ 30.92 KiB/125.66 KiB
# certifi    ------------------------------ 41.29 KiB/155.88 KiB
# logfire    ------------------------------ 14.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 30.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 14.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 47.57 KiB/224.50 KiB
# psutil     ------------------------------ 14.95 KiB/233.92 KiB
# ⠸ Preparing packages... (1/92)-- 30.92 KiB/237.53 KiB
# m2c2-datakit ------------------------------     0 B/52.29 KiB
# pexpect    ------------------------------ 16.00 KiB/62.28 KiB
# requests   ------------------------------ 30.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 62.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 52.49 KiB/64.23 KiB
# packaging  ------------------------------ 62.91 KiB/64.91 KiB
# idna       ------------------------------ 46.92 KiB/68.79 KiB
# traitlets  ------------------------------ 30.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 16.00 KiB/85.48 KiB
# parso      ------------------------------ 30.91 KiB/101.22 KiB
# jupyter-client ------------------------------ 15.89 KiB/103.62 KiB
# pyparsing  ------------------------------ 30.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 62.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 30.90 KiB/116.08 KiB
# urllib3    ------------------------------ 30.92 KiB/125.66 KiB
# certifi    ------------------------------ 57.29 KiB/155.88 KiB
# logfire    ------------------------------ 14.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 30.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 14.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 52.35 KiB/224.50 KiB
# psutil     ------------------------------ 14.95 KiB/233.92 KiB
# ⠸ Preparing packages... (1/92)-- 46.92 KiB/237.53 KiB
# m2c2-datakit ------------------------------     0 B/52.29 KiB
# pexpect    ------------------------------ 16.00 KiB/62.28 KiB
# requests   ------------------------------ 30.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 62.95 KiB/63.88 KiB
# opentelemetry-api ------------------------------ 64.23 KiB/64.23 KiB
# idna       ------------------------------ 46.92 KiB/68.79 KiB
# traitlets  ------------------------------ 30.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 16.00 KiB/85.48 KiB
# parso      ------------------------------ 30.91 KiB/101.22 KiB
# jupyter-client ------------------------------ 15.89 KiB/103.62 KiB
# pyparsing  ------------------------------ 30.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 78.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 30.90 KiB/116.08 KiB
# urllib3    ------------------------------ 30.92 KiB/125.66 KiB
# certifi    ------------------------------ 57.29 KiB/155.88 KiB
# logfire    ------------------------------ 14.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 30.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 14.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 52.35 KiB/224.50 KiB
# psutil     ------------------------------ 14.95 KiB/233.92 KiB
# rich       ------------------------------ 46.92 KiB/237.53 KiB
# ⠸ Preparing packages... (1/92)-- 16.00 KiB/247.46 KiB
# m2c2-datakit ------------------------------     0 B/52.29 KiB
# pexpect    ------------------------------ 16.00 KiB/62.28 KiB
# requests   ------------------------------ 30.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 62.95 KiB/63.88 KiB
# idna       ------------------------------ 46.92 KiB/68.79 KiB
# traitlets  ------------------------------ 30.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 16.00 KiB/85.48 KiB
# parso      ------------------------------ 30.91 KiB/101.22 KiB
# jupyter-client ------------------------------ 15.89 KiB/103.62 KiB
# pyparsing  ------------------------------ 30.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 78.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 30.90 KiB/116.08 KiB
# urllib3    ------------------------------ 30.92 KiB/125.66 KiB
# certifi    ------------------------------ 57.29 KiB/155.88 KiB
# logfire    ------------------------------ 14.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 30.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 14.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 52.35 KiB/224.50 KiB
# psutil     ------------------------------ 14.95 KiB/233.92 KiB
# rich       ------------------------------ 46.92 KiB/237.53 KiB
# contourpy  ------------------------------ 16.00 KiB/247.46 KiB
# ⠸ Preparing packages... (1/92)---------------- 62.79 KiB/287.63 KiB
# m2c2-datakit ------------------------------     0 B/52.29 KiB
# pexpect    ------------------------------ 16.00 KiB/62.28 KiB
# requests   ------------------------------ 30.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 62.95 KiB/63.88 KiB
# idna       ------------------------------ 46.92 KiB/68.79 KiB
# traitlets  ------------------------------ 30.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 16.00 KiB/85.48 KiB
# parso      ------------------------------ 30.91 KiB/101.22 KiB
# jupyter-client ------------------------------ 15.89 KiB/103.62 KiB
# pyparsing  ------------------------------ 30.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 78.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 30.90 KiB/116.08 KiB
# urllib3    ------------------------------ 30.92 KiB/125.66 KiB
# certifi    ------------------------------ 57.29 KiB/155.88 KiB
# logfire    ------------------------------ 14.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 30.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 14.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 52.35 KiB/224.50 KiB
# psutil     ------------------------------ 14.95 KiB/233.92 KiB
# rich       ------------------------------ 46.92 KiB/237.53 KiB
# contourpy  ------------------------------ 16.00 KiB/247.46 KiB
# ⠸ Preparing packages... (1/92)---------------- 62.79 KiB/287.63 KiB
# m2c2-datakit ------------------------------     0 B/52.29 KiB
# pexpect    ------------------------------ 32.00 KiB/62.28 KiB
# requests   ------------------------------ 30.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 62.95 KiB/63.88 KiB
# idna       ------------------------------ 46.92 KiB/68.79 KiB
# traitlets  ------------------------------ 30.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 32.00 KiB/85.48 KiB
# parso      ------------------------------ 30.91 KiB/101.22 KiB
# jupyter-client ------------------------------ 31.89 KiB/103.62 KiB
# pyparsing  ------------------------------ 46.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 78.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 30.90 KiB/116.08 KiB
# urllib3    ------------------------------ 30.92 KiB/125.66 KiB
# certifi    ------------------------------ 57.29 KiB/155.88 KiB
# logfire    ------------------------------ 14.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 30.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 30.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 52.35 KiB/224.50 KiB
# psutil     ------------------------------ 14.95 KiB/233.92 KiB
# rich       ------------------------------ 46.92 KiB/237.53 KiB
# contourpy  ------------------------------ 32.00 KiB/247.46 KiB
# ⠼ Preparing packages... (4/92)---------------- 62.79 KiB/287.63 KiB
# m2c2-datakit ------------------------------     0 B/52.29 KiB
# pexpect    ------------------------------ 32.00 KiB/62.28 KiB
# requests   ------------------------------ 46.91 KiB/63.41 KiB
# kiwisolver ------------------------------ 62.95 KiB/63.88 KiB
# idna       ------------------------------ 46.92 KiB/68.79 KiB
# traitlets  ------------------------------ 46.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 32.00 KiB/85.48 KiB
# parso      ------------------------------ 33.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 31.89 KiB/103.62 KiB
# pyparsing  ------------------------------ 46.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 78.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 46.90 KiB/116.08 KiB
# urllib3    ------------------------------ 46.92 KiB/125.66 KiB
# certifi    ------------------------------ 57.29 KiB/155.88 KiB
# logfire    ------------------------------ 30.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 46.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 30.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 52.35 KiB/224.50 KiB
# psutil     ------------------------------ 30.95 KiB/233.92 KiB
# rich       ------------------------------ 46.92 KiB/237.53 KiB
# contourpy  ------------------------------ 32.00 KiB/247.46 KiB
# ⠼ Preparing packages... (4/92)---------------- 62.79 KiB/287.63 KiB
# m2c2-datakit ------------------------------ 14.95 KiB/52.29 KiB
# pexpect    ------------------------------ 32.00 KiB/62.28 KiB
# requests   ------------------------------ 46.91 KiB/63.41 KiB
# idna       ------------------------------ 47.86 KiB/68.79 KiB
# traitlets  ------------------------------ 46.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 32.00 KiB/85.48 KiB
# parso      ------------------------------ 33.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 31.89 KiB/103.62 KiB
# pyparsing  ------------------------------ 46.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 78.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 46.90 KiB/116.08 KiB
# urllib3    ------------------------------ 46.92 KiB/125.66 KiB
# certifi    ------------------------------ 73.29 KiB/155.88 KiB
# logfire    ------------------------------ 30.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 46.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 30.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 68.35 KiB/224.50 KiB
# psutil     ------------------------------ 30.95 KiB/233.92 KiB
# rich       ------------------------------ 62.92 KiB/237.53 KiB
# contourpy  ------------------------------ 32.00 KiB/247.46 KiB
# googleapis-common-protos ------------------------------ 78.40 KiB/287.63 KiB
# ⠼ Preparing packages... (4/92)-- 48.00 KiB/288.00 KiB
# wrapt      ------------------------------     0 B/37.87 KiB
# typing-extensions ------------------------------     0 B/44.73 KiB
# h5netcdf   ------------------------------     0 B/48.40 KiB
# m2c2-datakit ------------------------------ 14.95 KiB/52.29 KiB
# pexpect    ------------------------------ 48.00 KiB/62.28 KiB
# requests   ------------------------------ 46.91 KiB/63.41 KiB
# idna       ------------------------------ 47.86 KiB/68.79 KiB
# traitlets  ------------------------------ 46.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 48.00 KiB/85.48 KiB
# parso      ------------------------------ 33.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 35.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 46.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 94.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 46.90 KiB/116.08 KiB
# urllib3    ------------------------------ 46.92 KiB/125.66 KiB
# certifi    ------------------------------ 73.29 KiB/155.88 KiB
# logfire    ------------------------------ 30.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 46.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 30.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 68.35 KiB/224.50 KiB
# psutil     ------------------------------ 30.95 KiB/233.92 KiB
# ⠼ Preparing packages... (4/92)-- 62.92 KiB/237.53 KiB
# wrapt      ------------------------------     0 B/37.87 KiB
# typing-extensions ------------------------------     0 B/44.73 KiB
# h5netcdf   ------------------------------     0 B/48.40 KiB
# m2c2-datakit ------------------------------ 14.95 KiB/52.29 KiB
# pexpect    ------------------------------ 48.00 KiB/62.28 KiB
# requests   ------------------------------ 46.91 KiB/63.41 KiB
# idna       ------------------------------ 47.86 KiB/68.79 KiB
# traitlets  ------------------------------ 62.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 48.00 KiB/85.48 KiB
# parso      ------------------------------ 49.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 35.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 62.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 94.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 62.90 KiB/116.08 KiB
# urllib3    ------------------------------ 62.92 KiB/125.66 KiB
# certifi    ------------------------------ 73.29 KiB/155.88 KiB
# logfire    ------------------------------ 30.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 46.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 46.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 68.35 KiB/224.50 KiB
# psutil     ------------------------------ 30.95 KiB/233.92 KiB
# ⠼ Preparing packages... (4/92)-- 62.92 KiB/237.53 KiB
# wrapt      ------------------------------ 14.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 14.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 14.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 30.95 KiB/52.29 KiB
# pexpect    ------------------------------ 48.00 KiB/62.28 KiB
# requests   ------------------------------ 62.81 KiB/63.41 KiB
# idna       ------------------------------ 63.86 KiB/68.79 KiB
# traitlets  ------------------------------ 62.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 48.00 KiB/85.48 KiB
# parso      ------------------------------ 49.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 35.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 62.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 94.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 62.90 KiB/116.08 KiB
# urllib3    ------------------------------ 62.92 KiB/125.66 KiB
# certifi    ------------------------------ 78.74 KiB/155.88 KiB
# logfire    ------------------------------ 46.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 62.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 46.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 76.81 KiB/224.50 KiB
# psutil     ------------------------------ 46.95 KiB/233.92 KiB
# ⠴ Preparing packages... (5/92)-- 73.45 KiB/237.53 KiB
# tabulate   ------------------------------     0 B/34.43 KiB
# wrapt      ------------------------------ 14.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 14.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 14.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 30.95 KiB/52.29 KiB
# requests   ------------------------------ 62.81 KiB/63.41 KiB
# idna       ------------------------------ 63.86 KiB/68.79 KiB
# traitlets  ------------------------------ 62.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 64.00 KiB/85.48 KiB
# parso      ------------------------------ 49.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 51.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 62.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 110.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 62.90 KiB/116.08 KiB
# urllib3    ------------------------------ 62.92 KiB/125.66 KiB
# certifi    ------------------------------ 78.74 KiB/155.88 KiB
# logfire    ------------------------------ 46.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 62.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 46.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 76.81 KiB/224.50 KiB
# psutil     ------------------------------ 46.95 KiB/233.92 KiB
# ⠴ Preparing packages... (5/92)-- 73.45 KiB/237.53 KiB
# tabulate   ------------------------------     0 B/34.43 KiB
# wrapt      ------------------------------ 14.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 14.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 14.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 30.95 KiB/52.29 KiB
# requests   ------------------------------ 62.81 KiB/63.41 KiB
# idna       ------------------------------ 63.86 KiB/68.79 KiB
# traitlets  ------------------------------ 62.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 64.00 KiB/85.48 KiB
# parso      ------------------------------ 49.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 51.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 62.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 110.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 62.90 KiB/116.08 KiB
# urllib3    ------------------------------ 62.92 KiB/125.66 KiB
# certifi    ------------------------------ 78.74 KiB/155.88 KiB
# logfire    ------------------------------ 46.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 62.89 KiB/190.37 KiB
# charset-normalizer ------------------------------ 62.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 76.81 KiB/224.50 KiB
# psutil     ------------------------------ 46.95 KiB/233.92 KiB
# ⠴ Preparing packages... (5/92)-- 73.45 KiB/237.53 KiB
# tabulate   ------------------------------     0 B/34.43 KiB
# wrapt      ------------------------------ 14.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 14.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 14.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 30.95 KiB/52.29 KiB
# idna       ------------------------------ 63.86 KiB/68.79 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 64.00 KiB/85.48 KiB
# parso      ------------------------------ 65.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 51.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 78.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 110.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 78.90 KiB/116.08 KiB
# urllib3    ------------------------------ 66.00 KiB/125.66 KiB
# certifi    ------------------------------ 78.74 KiB/155.88 KiB
# logfire    ------------------------------ 62.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 78.80 KiB/190.37 KiB
# charset-normalizer ------------------------------ 62.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 76.81 KiB/224.50 KiB
# psutil     ------------------------------ 62.95 KiB/233.92 KiB
# rich       ------------------------------ 73.45 KiB/237.53 KiB
# ⠴ Preparing packages... (5/92)-- 53.24 KiB/247.46 KiB
# tabulate   ------------------------------     0 B/34.43 KiB
# wrapt      ------------------------------ 14.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 14.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 14.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 30.95 KiB/52.29 KiB
# idna       ------------------------------ 63.86 KiB/68.79 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 64.00 KiB/85.48 KiB
# parso      ------------------------------ 65.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 51.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 78.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 110.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 78.90 KiB/116.08 KiB
# urllib3    ------------------------------ 66.00 KiB/125.66 KiB
# certifi    ------------------------------ 78.74 KiB/155.88 KiB
# logfire    ------------------------------ 62.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 78.80 KiB/190.37 KiB
# charset-normalizer ------------------------------ 62.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 76.81 KiB/224.50 KiB
# psutil     ------------------------------ 62.95 KiB/233.92 KiB
# rich       ------------------------------ 73.45 KiB/237.53 KiB
# ⠴ Preparing packages... (5/92)-- 53.24 KiB/247.46 KiB
# tabulate   ------------------------------     0 B/34.43 KiB
# wrapt      ------------------------------ 14.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 14.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 14.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 46.95 KiB/52.29 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 64.00 KiB/85.48 KiB
# parso      ------------------------------ 65.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 51.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 78.91 KiB/108.52 KiB
# ipykernel  ------------------------------ 110.91 KiB/114.43 KiB
# opentelemetry-sdk ------------------------------ 78.90 KiB/116.08 KiB
# urllib3    ------------------------------ 66.00 KiB/125.66 KiB
# certifi    ------------------------------ 78.74 KiB/155.88 KiB
# logfire    ------------------------------ 62.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 78.80 KiB/190.37 KiB
# charset-normalizer ------------------------------ 62.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 92.81 KiB/224.50 KiB
# psutil     ------------------------------ 62.95 KiB/233.92 KiB
# rich       ------------------------------ 77.81 KiB/237.53 KiB
# contourpy  ------------------------------ 53.24 KiB/247.46 KiB
# ⠴ Preparing packages... (5/92)---------------- 94.40 KiB/287.63 KiB
# tabulate   ------------------------------ 16.00 KiB/34.43 KiB
# wrapt      ------------------------------ 30.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 30.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 30.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 46.95 KiB/52.29 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 64.00 KiB/85.48 KiB
# parso      ------------------------------ 65.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 51.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 78.91 KiB/108.52 KiB
# opentelemetry-sdk ------------------------------ 78.90 KiB/116.08 KiB
# urllib3    ------------------------------ 66.00 KiB/125.66 KiB
# certifi    ------------------------------ 84.64 KiB/155.88 KiB
# logfire    ------------------------------ 62.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 78.80 KiB/190.37 KiB
# charset-normalizer ------------------------------ 62.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 92.81 KiB/224.50 KiB
# psutil     ------------------------------ 62.95 KiB/233.92 KiB
# rich       ------------------------------ 77.81 KiB/237.53 KiB
# contourpy  ------------------------------ 53.24 KiB/247.46 KiB
# googleapis-common-protos ------------------------------ 110.40 KiB/287.63 KiB
# ⠴ Preparing packages... (5/92)-- 63.87 KiB/288.00 KiB
# tabulate   ------------------------------ 16.00 KiB/34.43 KiB
# wrapt      ------------------------------ 30.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 30.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 30.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 46.95 KiB/52.29 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# markdown-it-py ------------------------------ 64.00 KiB/85.48 KiB
# parso      ------------------------------ 65.51 KiB/101.22 KiB
# jupyter-client ------------------------------ 51.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 78.91 KiB/108.52 KiB
# opentelemetry-sdk ------------------------------ 78.90 KiB/116.08 KiB
# urllib3    ------------------------------ 66.00 KiB/125.66 KiB
# certifi    ------------------------------ 84.64 KiB/155.88 KiB
# logfire    ------------------------------ 62.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 78.80 KiB/190.37 KiB
# charset-normalizer ------------------------------ 62.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 92.81 KiB/224.50 KiB
# psutil     ------------------------------ 62.95 KiB/233.92 KiB
# rich       ------------------------------ 77.81 KiB/237.53 KiB
# contourpy  ------------------------------ 65.61 KiB/247.46 KiB
# googleapis-common-protos ------------------------------ 110.40 KiB/287.63 KiB
# ⠴ Preparing packages... (5/92)-- 63.87 KiB/288.00 KiB
# tabulate   ------------------------------ 16.00 KiB/34.43 KiB
# wrapt      ------------------------------ 30.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 30.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 30.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 46.95 KiB/52.29 KiB
# markdown-it-py ------------------------------ 80.00 KiB/85.48 KiB
# parso      ------------------------------ 78.91 KiB/101.22 KiB
# jupyter-client ------------------------------ 67.69 KiB/103.62 KiB
# pyparsing  ------------------------------ 94.91 KiB/108.52 KiB
# opentelemetry-sdk ------------------------------ 83.16 KiB/116.08 KiB
# urllib3    ------------------------------ 75.80 KiB/125.66 KiB
# certifi    ------------------------------ 84.64 KiB/155.88 KiB
# logfire    ------------------------------ 62.92 KiB/189.91 KiB
# opentelemetry-semantic-conventions ------------------------------ 78.80 KiB/190.37 KiB
# charset-normalizer ------------------------------ 78.58 KiB/197.09 KiB
# python-dateutil ------------------------------ 92.81 KiB/224.50 KiB
# psutil     ------------------------------ 78.95 KiB/233.92 KiB
# rich       ------------------------------ 77.81 KiB/237.53 KiB
# contourpy  ------------------------------ 65.61 KiB/247.46 KiB
# googleapis-common-protos ------------------------------ 110.40 KiB/287.63 KiB
# seaborn    ------------------------------ 63.87 KiB/288.00 KiB
# ⠴ Preparing packages... (5/92)-- 76.61 KiB/339.69 KiB
# tabulate   ------------------------------ 16.00 KiB/34.43 KiB
# wrapt      ------------------------------ 30.95 KiB/37.87 KiB
# typing-extensions ------------------------------ 30.90 KiB/44.73 KiB
# h5netcdf   ------------------------------ 30.92 KiB/48.40 KiB
# m2c2-datakit ------------------------------ 46.95 KiB/52.29 KiB
# markdown-it-py ------------------------------ 80.00 KiB/85.48 KiB
# parso      ------------------------------ 78.91 KiB/101.22 KiB
# ...
# matplotlib ------------------------------ 6.78 MiB/7.67 MiB
# pandas     ------------------------------ 6.68 MiB/10.78 MiB
# ⠹ Preparing packages... (89/92)-- 6.76 MiB/21.33 MiB
# matplotlib ------------------------------ 6.82 MiB/7.67 MiB
# pandas     ------------------------------ 6.73 MiB/10.78 MiB
# ⠹ Preparing packages... (89/92)-- 6.81 MiB/21.33 MiB
# matplotlib ------------------------------ 6.89 MiB/7.67 MiB
# pandas     ------------------------------ 6.79 MiB/10.78 MiB
# ⠹ Preparing packages... (89/92)-- 6.87 MiB/21.33 MiB
# matplotlib ------------------------------ 6.95 MiB/7.67 MiB
# pandas     ------------------------------ 6.86 MiB/10.78 MiB
# ⠸ Preparing packages... (89/92)-- 6.92 MiB/21.33 MiB
# matplotlib ------------------------------ 7.00 MiB/7.67 MiB
# pandas     ------------------------------ 6.90 MiB/10.78 MiB
# ⠸ Preparing packages... (89/92)-- 6.98 MiB/21.33 MiB
# matplotlib ------------------------------ 7.04 MiB/7.67 MiB
# pandas     ------------------------------ 6.96 MiB/10.78 MiB
# ⠸ Preparing packages... (89/92)-- 7.04 MiB/21.33 MiB
# matplotlib ------------------------------ 7.11 MiB/7.67 MiB
# pandas     ------------------------------ 7.01 MiB/10.78 MiB
# ⠸ Preparing packages... (89/92)-- 7.10 MiB/21.33 MiB
# matplotlib ------------------------------ 7.15 MiB/7.67 MiB
# pandas     ------------------------------ 7.06 MiB/10.78 MiB
# ⠼ Preparing packages... (89/92)-- 7.15 MiB/21.33 MiB
# matplotlib ------------------------------ 7.21 MiB/7.67 MiB
# pandas     ------------------------------ 7.14 MiB/10.78 MiB
# ⠼ Preparing packages... (89/92)-- 7.21 MiB/21.33 MiB
# matplotlib ------------------------------ 7.28 MiB/7.67 MiB
# pandas     ------------------------------ 7.18 MiB/10.78 MiB
# ⠼ Preparing packages... (89/92)-- 7.26 MiB/21.33 MiB
# matplotlib ------------------------------ 7.34 MiB/7.67 MiB
# pandas     ------------------------------ 7.25 MiB/10.78 MiB
# ⠼ Preparing packages... (89/92)-- 7.32 MiB/21.33 MiB
# matplotlib ------------------------------ 7.39 MiB/7.67 MiB
# pandas     ------------------------------ 7.29 MiB/10.78 MiB
# ⠴ Preparing packages... (89/92)-- 7.38 MiB/21.33 MiB
# matplotlib ------------------------------ 7.45 MiB/7.67 MiB
# pandas     ------------------------------ 7.36 MiB/10.78 MiB
# ⠴ Preparing packages... (89/92)-- 7.43 MiB/21.33 MiB
# matplotlib ------------------------------ 7.51 MiB/7.67 MiB
# pandas     ------------------------------ 7.42 MiB/10.78 MiB
# ⠴ Preparing packages... (89/92)-- 7.49 MiB/21.33 MiB
# matplotlib ------------------------------ 7.56 MiB/7.67 MiB
# pandas     ------------------------------ 7.46 MiB/10.78 MiB
# ⠴ Preparing packages... (89/92)-- 7.54 MiB/21.33 MiB
# matplotlib ------------------------------ 7.61 MiB/7.67 MiB
# pandas     ------------------------------ 7.51 MiB/10.78 MiB
# ⠦ Preparing packages... (89/92)-- 7.60 MiB/21.33 MiB
# matplotlib ------------------------------ 7.65 MiB/7.67 MiB
# pandas     ------------------------------ 7.56 MiB/10.78 MiB
# ⠦ Preparing packages... (89/92)-- 7.65 MiB/21.33 MiB
# pandas     ------------------------------ 7.59 MiB/10.78 MiB
# ⠦ Preparing packages... (89/92)-- 7.67 MiB/21.33 MiB
# pandas     ------------------------------ 7.65 MiB/10.78 MiB
# ⠦ Preparing packages... (89/92)-- 7.71 MiB/21.33 MiB
# pandas     ------------------------------ 7.76 MiB/10.78 MiB
# ⠦ Preparing packages... (89/92)-- 7.79 MiB/21.33 MiB
# pandas     ------------------------------ 7.84 MiB/10.78 MiB
# ⠧ Preparing packages... (90/92)-- 7.90 MiB/21.33 MiB
# pandas     ------------------------------ 7.95 MiB/10.78 MiB
# ⠧ Preparing packages... (90/92)-- 7.98 MiB/21.33 MiB
# pandas     ------------------------------ 8.01 MiB/10.78 MiB
# ⠧ Preparing packages... (90/92)-- 8.09 MiB/21.33 MiB
# pandas     ------------------------------ 8.15 MiB/10.78 MiB
# ⠧ Preparing packages... (90/92)-- 8.15 MiB/21.33 MiB
# pandas     ------------------------------ 8.25 MiB/10.78 MiB
# ⠇ Preparing packages... (90/92)-- 8.21 MiB/21.33 MiB
# pandas     ------------------------------ 8.29 MiB/10.78 MiB
# ⠇ Preparing packages... (90/92)-- 8.31 MiB/21.33 MiB
# pandas     ------------------------------ 8.42 MiB/10.78 MiB
# ⠇ Preparing packages... (90/92)-- 8.37 MiB/21.33 MiB
# pandas     ------------------------------ 8.48 MiB/10.78 MiB
# ⠇ Preparing packages... (90/92)-- 8.48 MiB/21.33 MiB
# pandas     ------------------------------ 8.57 MiB/10.78 MiB
# ⠋ Preparing packages... (90/92)-- 8.54 MiB/21.33 MiB
# pandas     ------------------------------ 8.64 MiB/10.78 MiB
# ⠋ Preparing packages... (90/92)-- 8.65 MiB/21.33 MiB
# pandas     ------------------------------ 8.78 MiB/10.78 MiB
# ⠋ Preparing packages... (90/92)-- 8.73 MiB/21.33 MiB
# pandas     ------------------------------ 8.89 MiB/10.78 MiB
# ⠋ Preparing packages... (90/92)-- 8.79 MiB/21.33 MiB
# pandas     ------------------------------ 8.96 MiB/10.78 MiB
# ⠋ Preparing packages... (90/92)-- 8.92 MiB/21.33 MiB
# pandas     ------------------------------ 9.09 MiB/10.78 MiB
# ⠙ Preparing packages... (90/92)-- 8.98 MiB/21.33 MiB
# pandas     ------------------------------ 9.14 MiB/10.78 MiB
# ⠙ Preparing packages... (90/92)-- 9.07 MiB/21.33 MiB
# pandas     ------------------------------ 9.25 MiB/10.78 MiB
# ⠙ Preparing packages... (90/92)-- 9.15 MiB/21.33 MiB
# pandas     ------------------------------ 9.32 MiB/10.78 MiB
# ⠙ Preparing packages... (90/92)-- 9.26 MiB/21.33 MiB
# pandas     ------------------------------ 9.39 MiB/10.78 MiB
# ⠹ Preparing packages... (90/92)-- 9.37 MiB/21.33 MiB
# pandas     ------------------------------ 9.45 MiB/10.78 MiB
# ⠹ Preparing packages... (90/92)-- 9.46 MiB/21.33 MiB
# pandas     ------------------------------ 9.57 MiB/10.78 MiB
# ⠹ Preparing packages... (90/92)-- 9.51 MiB/21.33 MiB
# pandas     ------------------------------ 9.62 MiB/10.78 MiB
# ⠹ Preparing packages... (90/92)-- 9.63 MiB/21.33 MiB
# pandas     ------------------------------ 9.75 MiB/10.78 MiB
# ⠸ Preparing packages... (90/92)-- 9.70 MiB/21.33 MiB
# pandas     ------------------------------ 9.89 MiB/10.78 MiB
# ⠸ Preparing packages... (90/92)-- 9.78 MiB/21.33 MiB
# pandas     ------------------------------ 9.95 MiB/10.78 MiB
# ⠸ Preparing packages... (90/92)-- 9.90 MiB/21.33 MiB
# pandas     ------------------------------ 10.07 MiB/10.78 MiB
# ⠸ Preparing packages... (90/92)-- 9.98 MiB/21.33 MiB
# pandas     ------------------------------ 10.17 MiB/10.78 MiB
# ⠼ Preparing packages... (90/92)-- 10.09 MiB/21.33 MiB
# pandas     ------------------------------ 10.26 MiB/10.78 MiB
# ⠼ Preparing packages... (90/92)-- 10.17 MiB/21.33 MiB
# pandas     ------------------------------ 10.32 MiB/10.78 MiB
# ⠼ Preparing packages... (90/92)-- 10.31 MiB/21.33 MiB
# pandas     ------------------------------ 10.45 MiB/10.78 MiB
# ⠼ Preparing packages... (90/92)-- 10.42 MiB/21.33 MiB
# pandas     ------------------------------ 10.53 MiB/10.78 MiB
# ⠴ Preparing packages... (90/92)-- 10.53 MiB/21.33 MiB
# pandas     ------------------------------ 10.62 MiB/10.78 MiB
# ⠴ Preparing packages... (90/92)-- 10.62 MiB/21.33 MiB
# pandas     ------------------------------ 10.75 MiB/10.78 MiB
# ⠴ Preparing packages... (90/92)-- 10.71 MiB/21.33 MiB
# ⠴ Preparing packages... (90/92)-- 10.79 MiB/21.33 MiB
# ⠴ Preparing packages... (90/92)-- 10.88 MiB/21.33 MiB
# ⠦ Preparing packages... (91/92)-- 11.07 MiB/21.33 MiB
# ⠦ Preparing packages... (91/92)-- 11.29 MiB/21.33 MiB
# ⠦ Preparing packages... (91/92)-- 11.48 MiB/21.33 MiB
# ⠦ Preparing packages... (91/92)-- 11.68 MiB/21.33 MiB
# ⠧ Preparing packages... (91/92)-- 11.87 MiB/21.33 MiB
# ⠧ Preparing packages... (91/92)-- 12.07 MiB/21.33 MiB
# ⠧ Preparing packages... (91/92)-- 12.20 MiB/21.33 MiB
# ⠧ Preparing packages... (91/92)-- 12.29 MiB/21.33 MiB
# ⠇ Preparing packages... (91/92)-- 12.31 MiB/21.33 MiB
# ⠇ Preparing packages... (91/92)-- 12.63 MiB/21.33 MiB
# ⠇ Preparing packages... (91/92)-- 12.74 MiB/21.33 MiB
# ⠇ Preparing packages... (91/92)-- 12.91 MiB/21.33 MiB
# ⠋ Preparing packages... (91/92)-- 13.06 MiB/21.33 MiB
# ⠋ Preparing packages... (91/92)-- 13.23 MiB/21.33 MiB
# ⠋ Preparing packages... (91/92)-- 13.38 MiB/21.33 MiB
# ⠋ Preparing packages... (91/92)-- 13.54 MiB/21.33 MiB
# ⠙ Preparing packages... (91/92)-- 13.63 MiB/21.33 MiB
# ⠙ Preparing packages... (91/92)-- 13.79 MiB/21.33 MiB
# ⠙ Preparing packages... (91/92)-- 13.95 MiB/21.33 MiB
# ⠙ Preparing packages... (91/92)-- 14.12 MiB/21.33 MiB
# ⠹ Preparing packages... (91/92)-- 14.31 MiB/21.33 MiB
# ⠹ Preparing packages... (91/92)-- 14.45 MiB/21.33 MiB
# ⠹ Preparing packages... (91/92)-- 14.54 MiB/21.33 MiB
# ⠹ Preparing packages... (91/92)-- 14.78 MiB/21.33 MiB
# ⠹ Preparing packages... (91/92)-- 14.93 MiB/21.33 MiB
# ⠸ Preparing packages... (91/92)-- 15.09 MiB/21.33 MiB
# ⠸ Preparing packages... (91/92)-- 15.28 MiB/21.33 MiB
# ⠸ Preparing packages... (91/92)-- 15.31 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)-- 15.32 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)-- 15.32 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)-- 15.62 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)-- 15.75 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)-- 15.84 MiB/21.33 MiB
# ⠴ Preparing packages... (91/92)-- 16.00 MiB/21.33 MiB
# ⠴ Preparing packages... (91/92)-- 16.12 MiB/21.33 MiB
# ⠴ Preparing packages... (91/92)-- 16.25 MiB/21.33 MiB
# ⠴ Preparing packages... (91/92)-- 16.37 MiB/21.33 MiB
# ⠦ Preparing packages... (91/92)-- 16.50 MiB/21.33 MiB
# ⠦ Preparing packages... (91/92)-- 16.64 MiB/21.33 MiB
# ⠦ Preparing packages... (91/92)-- 16.80 MiB/21.33 MiB
# ⠦ Preparing packages... (91/92)-- 16.90 MiB/21.33 MiB
# ⠧ Preparing packages... (91/92)-- 17.05 MiB/21.33 MiB
# ⠧ Preparing packages... (91/92)-- 17.19 MiB/21.33 MiB
# ⠧ Preparing packages... (91/92)-- 17.32 MiB/21.33 MiB
# ⠧ Preparing packages... (91/92)-- 17.46 MiB/21.33 MiB
# ⠇ Preparing packages... (91/92)-- 17.57 MiB/21.33 MiB
# ⠇ Preparing packages... (91/92)-- 17.69 MiB/21.33 MiB
# ⠇ Preparing packages... (91/92)-- 17.82 MiB/21.33 MiB
# ⠇ Preparing packages... (91/92)-- 17.96 MiB/21.33 MiB
# ⠋ Preparing packages... (91/92)-- 18.11 MiB/21.33 MiB
# ⠋ Preparing packages... (91/92)-- 18.26 MiB/21.33 MiB
# ⠋ Preparing packages... (91/92)-- 18.41 MiB/21.33 MiB
# ⠋ Preparing packages... (91/92)-- 18.55 MiB/21.33 MiB
# ⠙ Preparing packages... (91/92)-- 18.69 MiB/21.33 MiB
# ⠙ Preparing packages... (91/92)-- 18.82 MiB/21.33 MiB
# ⠙ Preparing packages... (91/92)-- 18.96 MiB/21.33 MiB
# ⠙ Preparing packages... (91/92)-- 19.11 MiB/21.33 MiB
# ⠹ Preparing packages... (91/92)-- 19.21 MiB/21.33 MiB
# ⠹ Preparing packages... (91/92)-- 19.36 MiB/21.33 MiB
# ⠹ Preparing packages... (91/92)-- 19.51 MiB/21.33 MiB
# ⠹ Preparing packages... (91/92)-- 19.63 MiB/21.33 MiB
# ⠸ Preparing packages... (91/92)-- 19.76 MiB/21.33 MiB
# ⠸ Preparing packages... (91/92)m- 19.93 MiB/21.33 MiB
# ⠸ Preparing packages... (91/92)m- 20.02 MiB/21.33 MiB
# ⠸ Preparing packages... (91/92)m- 20.18 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)m- 20.30 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)m- 20.43 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)m- 20.58 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)2m 20.69 MiB/21.33 MiB
# ⠼ Preparing packages... (91/92)2m 20.88 MiB/21.33 MiB
# ⠴ Preparing packages... (91/92)2m 21.02 MiB/21.33 MiB
# Prepared 92 packages in 24.79s
# Installed 92 packages in 310ms
#  + annotated-types==0.7.0
#  + appnope==0.1.4
#  + arviz==0.21.0
#  + asttokens==3.0.0
#  + cachetools==5.5.2
#  + certifi==2025.4.26
#  + charset-normalizer==3.4.2
#  + cloudpickle==3.1.1
#  + comm==0.2.2
#  + cons==0.4.6
#  + contourpy==1.3.2
#  + cycler==0.12.1
#  + debugpy==1.8.14
#  + decorator==5.2.1
#  + deprecated==1.2.18
#  + etuples==0.3.9
#  + exceptiongroup==1.3.0
#  + executing==2.2.0
#  + filelock==3.18.0
#  + fonttools==4.58.0
#  + googleapis-common-protos==1.70.0
#  + h5netcdf==1.6.1
#  + h5py==3.13.0
#  + idna==3.10
#  + importlib-metadata==8.6.1
#  + ipykernel==6.29.5
#  + ipython==8.36.0
#  + jedi==0.19.2
#  + jupyter-client==8.6.3
#  + jupyter-core==5.7.2
#  + kiwisolver==1.4.8
#  + logfire==3.16.0
#  + logical-unification==0.4.6
#  + m2c2-datakit==0.1.78
#  + markdown-it-py==3.0.0
#  + matplotlib==3.10.3
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + minikanren==1.0.3
#  + multipledispatch==1.0.0
#  + nest-asyncio==1.6.0
#  + numpy==2.2.5
#  + opentelemetry-api==1.33.0
#  + opentelemetry-exporter-otlp-proto-common==1.33.0
#  + opentelemetry-exporter-otlp-proto-http==1.33.0
#  + opentelemetry-instrumentation==0.54b0
#  + opentelemetry-proto==1.33.0
#  + opentelemetry-sdk==1.33.0
#  + opentelemetry-semantic-conventions==0.54b0
#  + packaging==25.0
#  + pandas==2.2.3
#  + parso==0.8.4
#  + pexpect==4.9.0
#  + pillow==11.2.1
#  + platformdirs==4.3.8
#  + prompt-toolkit==3.0.51
#  + protobuf==5.29.4
#  + psutil==7.0.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pydantic==2.11.4
#  + pydantic-core==2.33.2
#  + pygments==2.19.1
#  + pymc==5.22.0
#  + pyparsing==3.2.3
#  + pytensor==2.30.3
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.0
#  + pytz==2025.2
#  + pyzmq==26.4.0
#  + requests==2.32.3
#  + rich==14.0.0
#  + scipy==1.15.3
#  + seaborn==0.13.2
#  + setuptools==80.6.0
#  + six==1.17.0
#  + stack-data==0.6.3
#  + tabulate==0.9.0
#  + threadpoolctl==3.6.0
#  + tomli==2.2.1
#  + toolz==1.0.0
#  + tornado==6.4.2
#  + traitlets==5.14.3
#  + typing-extensions==4.13.2
#  + typing-inspection==0.4.0
#  + tzdata==2025.2
#  + urllib3==2.4.0
#  + wcwidth==0.2.13
#  + wrapt==1.17.2
#  + xarray==2025.4.0
#  + xarray-einstats==0.8.0
#  + zipp==3.21.0
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement m2c2_datakit (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# ERROR: No matching distribution found for m2c2_datakit
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import glob
import json
import pandas as pd
from dotenv import load_dotenv
import m2c2_datakit as m2c2
m2c2.core.get_package_version()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 import pandas as pd
#       6 from dotenv import load_dotenv
# ----> 7 import m2c2_datakit as m2c2
#       8 m2c2.core.get_package_version()
#
# ModuleNotFoundError: No module named 'm2c2_datakit'

# %% [markdown]
# ## Configure output folder and summary functions

# %% [markdown]
# ## Step 1: Load Data

# %%
output_folder = "tidy"

summary_func_map = {
    "Symbol Search": m2c2.tasks.symbol_search.summarize,
    "Grid Memory": m2c2.tasks.grid_memory.summarize,
}

# ^ this also means that a user could specify their own summarize functions as needed!

# Data from REBOOT Study (UCF and PSU) was manually merged so we have two csvs to load
source_map = {
    "Symbol Search": "~/Documents/GitHub/datakit/data/reboot/m2c2kit_manualmerge_symbol_search_all_ts-20250402_151939.csv",
    "Grid Memory": "~/Documents/GitHub/datakit/data/reboot/m2c2kit_manualmerge_grid_memory_all_ts-20250402_151940.csv"
}

# Data from REBOOT Study (UCF and PSU) was manually merged so we have two csvs to load
mcsv = m2c2.core.pipeline.LASSIE().load(source_name="multicsv", source_map=source_map)
mcsv.assure(required_columns=['participant_id'])
mcsv.score()
mcsv.summarize(summary_func_map = summary_func_map)
ss = mcsv.grouped_summary.get("Symbol Search")

# %%
# %pip install pymc arviz

# %%
import pymc as pm
import arviz as az
import numpy as np
import pandas as pd

def flag_implausible_rts(df, participant_col='participant_id', rt_col='median_response_time_filtered',
                         correct_col='n_trials_correct', incorrect_col='n_trials_incorrect',
                         z_thresh=0.025, accuracy_thresh=0.6, samples=1000, tune=1000, chains=2):
    """
    Hierarchical Bayesian model using PyMC v4 (Aesara-based) to flag implausibly low RTs.

    Parameters:
        df (pd.DataFrame): Input dataframe.
        participant_col (str): Column containing participant IDs.
        rt_col (str): Column with response times.
        correct_col (str): Column with correct trial counts.
        incorrect_col (str): Column with incorrect trial counts.
        z_thresh (float): Quantile cutoff for credible interval (default 0.025).
        accuracy_thresh (float): Accuracy threshold below which low RT is considered implausible.
        samples (int): Number of posterior samples.
        tune (int): Number of tuning steps.
        chains (int): Number of chains.

    Returns:
        pd.DataFrame: Original dataframe with added columns:
            - accuracy_rate
            - rt_outlier (boolean)
            - implausible_rt (boolean)
    """
    df = df.copy()
    df = df.dropna(subset=[participant_col, rt_col, correct_col, incorrect_col])

    # Encode participants
    df['participant_idx'] = df[participant_col].astype('category').cat.codes
    n_participants = df['participant_idx'].nunique()

    rt_obs = df[rt_col].values
    participant_ids = df['participant_idx'].values
    accuracy_rate = df[correct_col] / (df[correct_col] + df[incorrect_col] + 1e-6)
    df['accuracy_rate'] = accuracy_rate

    with pm.Model() as model:
        # Hyperpriors
        mu_group = pm.Normal('mu_group', mu=1500, sigma=500)
        sigma_group = pm.HalfNormal('sigma_group', sigma=200)

        # Individual-level priors
        mu_individual = pm.Normal('mu_individual', mu=mu_group, sigma=sigma_group, shape=n_participants)
        sigma_individual = pm.HalfNormal('sigma_individual', sigma=100, shape=n_participants)

        # Likelihood
        rt = pm.Normal('rt', mu=mu_individual[participant_ids],
                       sigma=sigma_individual[participant_ids],
                       observed=rt_obs)

        # Sample posterior
        trace = pm.sample(draws=samples, tune=tune, chains=chains, target_accept=0.9)

        # Posterior predictive
        ppc = pm.sample_posterior_predictive(trace, model=model, var_names=["rt"])

    # Get bounds from posterior predictive
    ppc_rt = ppc["rt"]  # shape: (samples * chains, n_obs)
    lower_bounds = np.percentile(ppc_rt, 100 * z_thresh, axis=0)
    upper_bounds = np.percentile(ppc_rt, 100 * (1 - z_thresh), axis=0)

    # Flag outliers
    df['rt_outlier'] = (rt_obs < lower_bounds) | (rt_obs > upper_bounds)
    df['implausible_rt'] = df['rt_outlier'] & (df['accuracy_rate'] < accuracy_thresh)

    return df

# Assuming your DataFrame is called `a`
df_flagged = flag_implausible_rts(a)
df_flagged[df_flagged['implausible_rt']]
